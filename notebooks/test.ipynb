# %%
from backtest import node
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from backtest import node
#
# File /opt/pysetup/tutorials/notebooks/backtest.py:4
#       2 from nautilus_trader.config import BacktestRunConfig, BacktestVenueConfig
#       3 from nautilus_trader.test_kit.providers import TestInstrumentProvider
# ----> 4 from strategies.ema_cross import EMACross, EMACrossConfig
#       6 # 1. Configure the Backtest
#       7 config = BacktestRunConfig(
#       8     engine_seed=42,
#       9     venues=[
#    (...)     18     # ...
#      19 )
#
# File /opt/pysetup/tutorials/notebooks/strategies/ema_cross.py:2
#       1 from nautilus_trader.config import StrategyConfig
# ----> 2 from nautilus_trader.core.message import OrderSide
#       3 from nautilus_trader.trading.strategy import Strategy
#       4 from nautilus_trader.trading.events import Bar
#
# ...

# %%
results = node.run()
